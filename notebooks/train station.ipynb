# %%
import openrouteservice as ors
import folium
client = ors.Client(key='5b3ce3597851110001cf624891b5abbb2a54483d8a600850ca8c548f')

# %%
import googlemaps
api_key='AIzaSyDDSlAk-E9vsr84WwNnvdhsvRgGHODj0AI'
gmaps = googlemaps.Client(api_key)

import pandas as pd

df = pd.read_csv('../data/curated/Rental_Property_Data.csv')

print(df)
col= ['distance to melb central in km']
dis= pd.DataFrame(columns=col)
print(dis)
a=[]
cord=[]
loc2=[144.961602, -37.813937]
cord.append(loc2)



print(df['Addresses'])

for i in df['Addresses']:
    result = gmaps.geocode(i)
    lat= result[0]["geometry"]['location']['lat']
    lang=result[0]["geometry"]['location']['lng']
    loc1=[lang,lat]
    
    
    cord.append(loc1)


    #a.append(hs.haversine(loc1,loc2))
dis['distance to melb central in km']=a
print(cord)
# Out:
#       Unnamed: 0                    Suburbs  \
# 0              0           BONSHAW VIC 3352
# 1              1       KEILOR EAST VIC 3033
# 2              2         ALFREDTON VIC 3350
# 3              3     NORTH BENDIGO VIC 3550
# 4              4         BEVERIDGE VIC 3753
# ...          ...                        ...
# 1995        1995  MANIFOLD HEIGHTS VIC 3218
# 1996        1996         GLEN IRIS VIC 3146
# 1997        1997       SOUTH YARRA VIC 3141
# 1998        1998            FOSTER VIC 3960
# 1999        1999         MELBOURNE VIC 3000
#
#                                               Addresses Price per week ($)  \
# 0                   26 Yolanda Street, BONSHAW VIC 3352               $460
# 1              55 Berembong Drive, KEILOR EAST VIC 3033            $425.00
# 2                  43 Lugano Avenue, ALFREDTON VIC 3350            $420.00
# 3        34 St James Wood Drive, NORTH BENDIGO VIC 3550            $460.00
# ...

# %%
m = folium.Map(location=[-37.813937, 144.961602], tiles='cartodbpositron', zoom_start=13)

# Some coordinates in Berlin
geojson = {"type": "point", "coordinates": [144.961602, -37.813937]}

pois = client.places(
    request='pois',
    geojson=geojson,
    buffer=600,  # searches within 500 meters of specified point
    filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
    validate=False,
#     dry_run=True
)

# %%
pois['features'][0]['properties']['distance']
# Out:
# 442.86210388

# %%
len(cord)
# Out:
# 2001

# %% [markdown]
# ## First 500

# %%
distance = []

# %%
for i in cord[1:31]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[31:61]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[61:81]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[81:101]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])
# Out:
# /home/jericho/miniconda3/envs/ads/lib/python3.8/site-packages/openrouteservice/client.py:211: UserWarning: Rate limit exceeded. Retrying for the 1st time.
#   warnings.warn('Rate limit exceeded. Retrying for the {0}{1} time.'.format(retry_counter + 1,

# %%
for i in cord[101:121]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[121:141]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[141:161]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[161:181]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[181:201]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[201:231]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])
# Out:
# /home/jericho/miniconda3/envs/ads/lib/python3.8/site-packages/openrouteservice/client.py:211: UserWarning: Rate limit exceeded. Retrying for the 2nd time.
#   warnings.warn('Rate limit exceeded. Retrying for the {0}{1} time.'.format(retry_counter + 1,
# /home/jericho/miniconda3/envs/ads/lib/python3.8/site-packages/openrouteservice/client.py:211: UserWarning: Rate limit exceeded. Retrying for the 3rd time.
#   warnings.warn('Rate limit exceeded. Retrying for the {0}{1} time.'.format(retry_counter + 1,

# %%
for i in cord[231:251]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[251:271]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[271:291]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])
# Out:
# /home/jericho/miniconda3/envs/ads/lib/python3.8/site-packages/openrouteservice/client.py:211: UserWarning: Rate limit exceeded. Retrying for the 4th time.
#   warnings.warn('Rate limit exceeded. Retrying for the {0}{1} time.'.format(retry_counter + 1,
# /home/jericho/miniconda3/envs/ads/lib/python3.8/site-packages/openrouteservice/client.py:211: UserWarning: Rate limit exceeded. Retrying for the 5th time.
#   warnings.warn('Rate limit exceeded. Retrying for the {0}{1} time.'.format(retry_counter + 1,

# %%
for i in cord[291:311]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[311:331]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[331:351]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[351:371]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[371:391]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[391:411]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[411:431]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[431:451]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[451:471]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[471:491]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[491:501]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
len(distance)
# Out:
# 480

# %%
distance
# Out:
# ['None',
#  'None',
#  'None',
#  'None',
#  'None',
#  1128.93061684,
#  826.64727634,
#  876.48509914,
#  643.7014872,
#  1836.8815845,
#  1246.89324495,
#  'None',
#  692.59426628,
#  1775.40321601,
#  'None',
#  'None',
#  'None',
#  895.22285443,
#  'None',
#  'None',
#  1360.00501712,
#  669.33217546,
#  988.5474374,
#  'None',
#  1326.92903682,
#  'None',
#  'None',
#  'None',
#  1766.15717994,
#  'None',
#  'None',
#  1376.79136087,
#  1044.73960086,
#  1893.91115003,
#  848.04830471,
#  1048.05745198,
#  1437.35742943,
#  943.19385642,
#  'None',
#  'None',
#  'None',
#  871.58104766,
#  1323.12596781,
#  1257.57528661,
#  1257.57528661,
#  'None',
#  'None',
#  1416.10935963,
#  1786.23158059,
#  'None',
#  1615.36970108,
#  1300.4378246,
#  'None',
#  1056.81460155,
#  1056.81460155,
#  'None',
#  1462.90895869,
#  'None',
#  'None',
#  'None',
#  'None',
#  412.84793551,
#  1713.87738563,
#  365.88751218,
#  'None',
#  'None',
#  1472.42096293,
#  1980.82363038,
# ...

# %% [markdown]
# ## 500 -1000

# %%
client = ors.Client(key='5b3ce3597851110001cf6248fa44620f407f4fc2b8ece979d073b51e')

# %%
for i in cord[501:521]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %% [markdown]
# ## 1000-1500

# %%
client = ors.Client(key='5b3ce3597851110001cf624828611af684c746e9b1de6fe3a97c8289')
