# %%
import openrouteservice as ors
import folium
client = ors.Client(key='5b3ce3597851110001cf624891b5abbb2a54483d8a600850ca8c548f')

# %%
import googlemaps
api_key='AIzaSyDDSlAk-E9vsr84WwNnvdhsvRgGHODj0AI'
gmaps = googlemaps.Client(api_key)

import pandas as pd

df = pd.read_csv('../data/curated/Curated_Rental_Property_Data.csv')

print(df)
col= ['distance to melb central in km']
dis= pd.DataFrame(columns=col)
print(dis)
a=[]
cord=[]
loc2=[144.961602, -37.813937]
cord.append(loc2)



print(df['address'])

for i in df['address']:
    result = gmaps.geocode(i)
    lat= result[0]["geometry"]['location']['lat']
    lang=result[0]["geometry"]['location']['lng']
    loc1=[lang,lat]
    
    
    cord.append(loc1)


    #a.append(hs.haversine(loc1,loc2))
dis['distance to melb central in km']=a
print(cord)
# Out:
#       Unnamed: 0.1  Unnamed: 0  \
# 0                0           0
# 1                1           1
# 2                2           2
# 3                3           3
# 4                4           4
# ...            ...         ...
# 2976          2976        2995
# 2977          2977        2996
# 2978          2978        2997
# 2979          2979        2998
# 2980          2980        2999
#
#                                           property_link  \
# 0     https://www.domain.com.au/14-curringa-ct-churc...
# 1     https://www.domain.com.au/31-suzanne-street-da...
# 2     https://www.domain.com.au/65-bruckner-drive-po...
# 3     https://www.domain.com.au/16-june-square-ringw...
# 4     https://www.domain.com.au/1-76-mckean-street-b...
# ...                                                 ...
# 2976  https://www.domain.com.au/2-7-finchley-av-glen...
# 2977  https://www.domain.com.au/2b-parklands-crescen...
# 2978  https://www.domain.com.au/38-luxe-terrace-poin...
# 2979  https://www.domain.com.au/97a-ogilvie-street-e...
# 2980  https://www.domain.com.au/32-jessie-st-richmon...
#
#                        suburb                                        address  \
# 0          CHURCHILL VIC 3842             14 Curringa Ct, CHURCHILL VIC 3842
# 1          DANDENONG VIC 3175          31 Suzanne Street, DANDENONG VIC 3175
# 2         POINT COOK VIC 3030         65 Bruckner Drive, POINT COOK VIC 3030
# 3     RINGWOOD NORTH VIC 3134        16 June Square, RINGWOOD NORTH VIC 3134
# 4     BOX HILL NORTH VIC 3129    1/76 McKean Street, BOX HILL NORTH VIC 3129
# ...                       ...                                            ...
# 2976         GLENROY VIC 3046              2/7 Finchley Av, GLENROY VIC 3046
# 2977   BRIGHTON EAST VIC 3187  2B Parklands Crescent, BRIGHTON EAST VIC 3187
# 2978      POINT COOK VIC 3030           38 Luxe Terrace, POINT COOK VIC 3030
# 2979        ESSENDON VIC 3040          97A Ogilvie Street, ESSENDON VIC 3040
# 2980        RICHMOND VIC 3121                32 Jessie St, RICHMOND VIC 3121
#
#       property_type  price  closest_school  Bedrooms  Bathrooms  Garages
# 0                 0    320             1.0         3          1        0
# 1                 0    465             0.7         3          1        1
# 2                 0    420             1.3         4          2        2
# 3                 0    620             0.5         3          2        6
# 4                 0    620             0.7         4          2        1
# ...             ...    ...             ...       ...        ...      ...
# 2976              1    390             0.5         2          1        1
# 2977              1     14             0.6         4          3        2
# 2978              1    480             0.6         3          2        2
# 2979              1    980             0.4         4          2        2
# 2980              1    830             1.0         3          2        1
#
# [2981 rows x 11 columns]
# Empty DataFrame
# Columns: [distance to melb central in km]
# Index: []
# 0                  14 Curringa Ct, CHURCHILL VIC 3842
# 1               31 Suzanne Street, DANDENONG VIC 3175
# 2              65 Bruckner Drive, POINT COOK VIC 3030
# 3             16 June Square, RINGWOOD NORTH VIC 3134
# 4         1/76 McKean Street, BOX HILL NORTH VIC 3129
#                             ...
# 2976                2/7 Finchley Av, GLENROY VIC 3046
# 2977    2B Parklands Crescent, BRIGHTON EAST VIC 3187
# 2978             38 Luxe Terrace, POINT COOK VIC 3030
# 2979            97A Ogilvie Street, ESSENDON VIC 3040
# 2980                  32 Jessie St, RICHMOND VIC 3121
# Name: address, Length: 2981, dtype: object
# [[144.961602, -37.813937], [146.420834, -38.3190719], [145.2153698, -37.9705165], [144.7117524, -37.8967255], [145.2172253, -37.79795379999999], [145.1387258, -37.8141851], [144.3470354, -38.1800726], [145.1688663, -37.9377616], [142.7837111, -38.3679298], [145.3879729, -38.0622878], [144.9809542, -37.7959254], [144.3477282, -38.2239113], [145.2274096, -37.9813218], [144.7571884, -37.8715354], [144.3535563, -38.1951208], [144.9909381, -37.86379609999999], [143.5778748, -38.3401364], [144.397246, -38.0188922], [145.3337697, -38.0328778], [145.3155371, -37.8064517], [144.7837578, -37.7290041], [146.2356786, -36.9515447], [146.4186037, -38.2278786], [144.5541228, -37.6950645], [144.6695652, -37.8274276], [145.1345353, -37.6091555], [145.4432458, -38.0625413], [145.2821062, -38.0823995], [145.2025551, -37.8254135], [144.3483165, -38.0666751], [144.7375779, -37.714748], [144.6506958, -37.8309309], [145.148599, -37.7848979], [144.9384928, -37.7011544], [145.9518473, -38.4702959], [144.7705364, -37.7045631], [144.8379104, -37.7802491], [145.3667018, -38.0503822], [145.3380043, -38.0547288], [145.1738754, -37.8169653], [145.4101982, -36.37049], [144.7557088, -37.9019653], [146.3177913, -36.3816517], [145.1821504, -37.7738236], [145.1967062, -38.0831589], [144.7643986, -37.7331504], [144.7577248, -36.1384027], [144.9589202, -37.5340693], [144.9982547, -37.6606188], [145.1390707, -38.1603629], [144.8349893, -37.7825354], [145.2783493, -37.8731594], [144.9070586, -37.6008597], [145.4819974, -38.0729145], [144.9533347, -37.5193347], [144.6097952, -37.8926519], [145.0509525, -37.8326482], [145.0509525, -37.8326482], [144.8717252, -37.7227974], [144.988356, -37.6658979], [144.3791956, -38.1760962], [142.5868811, -38.2811401], [144.8068145, -37.7527484], [144.9737683, -37.7736604], [144.9652922, -37.85435830000001], [145.405787, -38.0576376], [145.0495313, -37.69728620000001], [144.6601819, -37.89688599999999], [142.1279004, -34.211586], [145.0828929, -37.73674159999999], [144.9316116, -37.6828098], [144.3378553, -38.1013848], [145.1228191, -37.9009763], [144.8087899, -37.7923011], [144.5504198, -37.6647974], [145.0897865, -37.8588397], [144.988157, -37.855236], [144.9927457, -37.8729812], [144.5707991, -37.731282], [144.8670796, -37.8122164], [145.2870078, -37.9185113], [144.2367805, -36.7809765], [145.0348221, -37.7517316], [144.7121743, -37.82297], [144.2612526, -36.7076358], [144.7708905, -37.7809636], [145.0288759, -37.9578215], [145.2015915, -37.8137227], [144.6173824, -37.8741559], [143.8586352, -37.5776381], [145.0662422, -37.6070166], [143.8192454, -37.6020923], [145.132712, -38.1064235], [144.326627, -38.1282466], [144.5829305, -37.8650288], [144.9692505, -37.7728574], [144.8814812, -37.8063714], [145.268159, -38.045627], [144.9637864, -37.737656], [144.5873504, -37.6774164], [145.00908, -37.63020059999999], [144.7705793, -37.78653500000001], [144.6400456, -37.9020445], [144.6916811, -37.8388886], [145.944213, -38.15341], [145.0603018, -37.8311559], [144.2944452, -38.1687347], [144.7583536, -37.9041232], [144.6203511, -37.71955500000001], [145.197076, -37.9158845], [145.1349816, -37.9586809], [144.4323116, -37.6752201], [145.111063, -37.816251], [145.1597239, -37.8058305], [145.0564262, -37.8495753], [145.0802864, -37.9050209], [144.305925, -36.7667391], [144.3716385, -38.0200723], [144.7906179, -37.7565486], [144.3424025, -38.1406691], [144.8361491, -37.7183071], [144.6831031, -37.8135157], [144.883083, -37.815936], [145.100365, -37.8080532], [145.0501253, -37.663021], [145.0936645, -37.6479516], [144.9865916, -37.7013908], [144.6846916, -37.8362352], [147.0842553, -38.1010135], [144.3595051, -38.1567684], [144.7276281, -37.8992365], [144.5693938, -37.7237198], [145.2874942, -37.8414667], [145.3008069, -37.7867641], [145.0309287, -37.7270473], [144.7060694, -37.9631943], [144.6586255, -37.8345288], [144.8882893, -37.616991], [144.4389535, -37.65686520000001], [144.8838882, -37.8071547], [145.8793535, -36.1652762], [144.7251609, -3 ...

# %%
m = folium.Map(location=[-37.813937, 144.961602], tiles='cartodbpositron', zoom_start=13)

# Some coordinates in Berlin
geojson = {"type": "point", "coordinates": [144.961602, -37.813937]}

pois = client.places(
    request='pois',
    geojson=geojson,
    buffer=600,  # searches within 500 meters of specified point
    filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
    validate=False,
#     dry_run=True
)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File ~/miniconda3/envs/ads/lib/python3.8/http/client.py:1348, in HTTPConnection.getresponse(self)
#    1347 try:
# -> 1348     response.begin()
#    1349 except ConnectionError:
#
# File ~/miniconda3/envs/ads/lib/python3.8/http/client.py:316, in HTTPResponse.begin(self)
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#
# File ~/miniconda3/envs/ads/lib/python3.8/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#
# File ~/miniconda3/envs/ads/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     668 try:
# --> 669     return self._sock.recv_into(b)
#     670 except timeout:
#
# File ~/miniconda3/envs/ads/lib/python3.8/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#
# File ~/miniconda3/envs/ads/lib/python3.8/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1098 if buffer is not None:
# -> 1099     return self._sslobj.read(len, buffer)
#    1100 else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/urllib3/util/retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/urllib3/packages/six.py:770, in reraise(tp, value, tb)
#     769         raise value.with_traceback(tb)
# --> 770     raise value
#     771 finally:
#
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/urllib3/connectionpool.py:451, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     452     raise
#
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/urllib3/connectionpool.py:340, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     339 if isinstance(err, SocketTimeout):
# --> 340     raise ReadTimeoutError(
#     341         self, url, "Read timed out. (read timeout=%s)" % timeout_value
#     342     )
#     344 # See the above comment about EAGAIN in Python 3. In Python 2 we have
#     345 # to specifically catch it and throw the timeout error
#
# ReadTimeoutError: HTTPSConnectionPool(host='api.openrouteservice.org', port=443): Read timed out. (read timeout=60)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/openrouteservice/client.py:186, in Client.request(self, url, get_params, first_request_time, retry_counter, requests_kwargs, post_json, dry_run)
#     185 try:
# --> 186     response = requests_method(self._base_url + authed_url,
#     187                                **final_requests_kwargs)
#     188     self._req = response.request
#
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/requests/sessions.py:635, in Session.post(self, url, data, json, **kwargs)
#     625 r"""Sends a POST request. Returns :class:`Response` object.
#     626
#     627 :param url: URL for the new :class:`Request` object.
#    (...)
#     632 :rtype: requests.Response
#     633 """
# --> 635 return self.request("POST", url, data=data, json=json, **kwargs)
#
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/requests/adapters.py:578, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     577 elif isinstance(e, ReadTimeoutError):
# --> 578     raise ReadTimeout(e, request=request)
#     579 elif isinstance(e, _InvalidHeader):
#
# ReadTimeout: HTTPSConnectionPool(host='api.openrouteservice.org', port=443): Read timed out. (read timeout=60)
#
# During handling of the above exception, another exception occurred:
#
# Timeout                                   Traceback (most recent call last)
# /home/jericho/Project 2/generic-real-estate-consulting-project-group-29/notebooks/train station.ipynb Cell 4 in <cell line: 6>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jericho/Project%202/generic-real-estate-consulting-project-group-29/notebooks/train%20station.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> # Some coordinates in Berlin
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jericho/Project%202/generic-real-estate-consulting-project-group-29/notebooks/train%20station.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> geojson = {"type": "point", "coordinates": [144.961602, -37.813937]}
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jericho/Project%202/generic-real-estate-consulting-project-group-29/notebooks/train%20station.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> pois = client.places(
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jericho/Project%202/generic-real-estate-consulting-project-group-29/notebooks/train%20station.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>     request='pois',
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jericho/Project%202/generic-real-estate-consulting-project-group-29/notebooks/train%20station.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>     geojson=geojson,
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jericho/Project%202/generic-real-estate-consulting-project-group-29/notebooks/train%20station.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a>     buffer=600,  # searches within 500 meters of specified point
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jericho/Project%202/generic-real-estate-consulting-project-group-29/notebooks/train%20station.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a>     filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jericho/Project%202/generic-real-estate-consulting-project-group-29/notebooks/train%20station.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>     validate=False,
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jericho/Project%202/generic-real-estate-consulting-project-group-29/notebooks/train%20station.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> #     dry_run=True
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jericho/Project%202/generic-real-estate-consulting-project-group-29/notebooks/train%20station.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> )
#
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/openrouteservice/client.py:299, in _make_api_method.<locals>.wrapper(*args, **kwargs)
#     296 @functools.wraps(func)
#     297 def wrapper(*args, **kwargs):
#     298     args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 299     result = func(*args, **kwargs)
#     300     try:
#     301         del args[0]._extra_params
#
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/openrouteservice/places.py:115, in places(client, request, geojson, bbox, buffer, filter_category_ids, filter_category_group_ids, filters_custom, limit, sortby, validate, dry_run)
#     112     if sortby:
#     113         params['sortby'] = sortby
# --> 115 return client.request('/pois', {}, post_json=params, dry_run=dry_run)
#
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/openrouteservice/client.py:191, in Client.request(self, url, get_params, first_request_time, retry_counter, requests_kwargs, post_json, dry_run)
#     188     self._req = response.request
#     190 except requests.exceptions.Timeout:
# --> 191     raise exceptions.Timeout()
#     193 if response.status_code in _RETRIABLE_STATUSES:
#     194     # Retry request.
#     195     warnings.warn('Server down.\nRetrying for the {0}{1} time.'.format(retry_counter + 1,
#     196                                                                        get_ordinal(retry_counter + 1)),
#     197                   UserWarning,
#     198                   stacklevel=1)
#
# Timeout:

# %%
pois['features'][0]['properties']['distance']
# Out:
# 442.86210388

# %%
len(cord)
# Out:
# 2001

# %% [markdown]
# ## First 500

# %%
distance = []

# %%
for i in cord[1:21]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[21:41]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[41:61]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[61:81]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[81:101]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[101:121]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[121:141]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[141:161]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[161:181]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[181:201]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[201:231]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[231:251]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[251:271]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[271:291]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[291:311]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[311:331]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[331:351]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[351:371]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[371:391]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[391:411]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[411:431]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[431:451]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[451:471]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[471:491]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[491:501]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
len(distance)
# Out:
# 500

# %%
df = pd.DataFrame (distance)
df
# Out:
#                0
# 0           None
# 1           None
# 2           None
# 3           None
# 4           None
# ..           ...
# 495         None
# 496   938.755088
# 497  1004.667689
# 498         None
# 499         None
#
# [500 rows x 1 columns]

# %%
df.to_csv("distance500.csv")

# %% [markdown]
# ## 500 -1000

# %%
client = ors.Client(key='5b3ce3597851110001cf624828611af684c746e9b1de6fe3a97c8289')

# %%
distance=[]

# %%
for i in cord[501:521]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[521:541]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[541:561]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[561:581]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[581:601]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[601:621]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[621:641]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[641:661]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[661:681]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[681:701]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[701:721]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[721:741]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[741:761]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[761:781]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[781:801]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[801:821]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[821:841]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[841:861]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[861:881]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[881:901]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[901:921]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[921:941]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[941:961]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[961:981]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[981:1001]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
df = pd.DataFrame (distance)
df
# Out:
#                0
# 0     991.975513
# 1     630.145331
# 2    1158.299447
# 3           None
# 4     1940.59838
# ..           ...
# 495  1857.464267
# 496   617.764091
# 497         None
# 498  1455.729485
# 499   852.031203
#
# [500 rows x 1 columns]

# %%
df.to_csv("distance1000.csv")

# %% [markdown]
# ## 1000-1500

# %%
client = ors.Client(key='5b3ce3597851110001cf62485055b580ee7f4e1cb6cb5690fa4ab867')

# %%
distance=[]

# %%
for i in cord[1001:1021]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1021:1041]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1041:1061]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1061:1081]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1081:1101]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1101:1121]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1121:1141]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1141:1161]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1161:1181]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1181:1201]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1201:1221]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1221:1241]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1241:1261]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1261:1281]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1281:1301]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1301:1321]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1321:1341]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1341:1361]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1361:1381]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1381:1401]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1401:1421]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1421:1441]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1441:1461]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1461:1481]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1481:1501]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
df = pd.DataFrame (distance)
df
# Out:
#                0
# 0    1054.305441
# 1     981.876049
# 2    1862.279805
# 3    1837.008044
# 4    1241.344342
# ..           ...
# 495    1826.3797
# 496  1414.473755
# 497  1564.425413
# 498  1320.657876
# 499  1422.696965
#
# [500 rows x 1 columns]

# %%
df.to_csv("distance1500.csv")

# %% [markdown]
# ## 1500-2000

# %%
client = ors.Client(key='5b3ce3597851110001cf62488c65290264c547e3a87223f862e7debe')

# %%
for i in cord[1501:1521]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1521:1541]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1541:1561]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1561:1581]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1581:1601]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1601:1621]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1621:1641]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1641:1661]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1661:1681]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1681:1701]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1701:1721]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1721:1741]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1741:1761]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1761:1781]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1781:1801]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1801:1821]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1821:1841]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1841:1861]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1861:1881]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1881:1901]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1901:1921]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1921:1941]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1941:1961]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1961:1981]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[1981:2001]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
distance
# Out:
# [528.00941049,
#  1874.73911464,
#  1897.71758518,
#  382.22935743,
#  1518.40926845,
#  1114.9687331,
#  1719.38598714,
#  793.5051941,
#  1305.34496473,
#  708.90049822,
#  1420.06253696,
#  1893.86157489,
#  1792.3368455,
#  1901.42203275,
#  1584.87056987,
#  1502.023239,
#  1925.08508541,
#  'None',
#  1016.79332245,
#  1183.47343249,
#  481.37110779,
#  611.19700216,
#  'None',
#  1071.19180748,
#  891.36520282,
#  1791.79499542,
#  1819.41315071,
#  176.2253789,
#  1014.41086023,
#  'None',
#  617.81663741,
#  1270.64438194,
#  1512.22517723,
#  145.22090744,
#  1735.78054825,
#  'None',
#  1502.48964242,
#  1515.15281613,
#  1252.79151158,
#  1450.11887784,
#  1032.40758536,
#  1302.42340247,
#  1860.22949056,
#  1565.95278639,
#  1723.51980818,
#  'None',
#  1953.51926326,
#  363.80652903,
#  'None',
#  720.71720685,
#  487.41582311,
#  1930.99149545,
#  1927.41532058,
#  387.83782141,
#  1782.75917907,
#  1920.44435564,
#  400.71844723,
#  1202.67135826,
#  464.68086912,
#  1492.18486208,
#  234.97519393,
#  887.76065418,
#  1675.57767573,
#  235.86681951,
#  1048.05745199,
#  311.06857343,
#  1510.43590266,
#  1121.69914751,
#  1865.70344368,
#  1402.55639704,
#  1354.1202544,
#  1250.33280464,
#  408.94991414,
#  1614.09248808,
#  1943.70155375,
#  'None',
#  405.67642965,
#  827.00868881,
#  1121.69914751,
#  1621.46140112,
#  1460.79309351,
#  1194.65429323,
#  1360.42391894,
#  1611.77216252,
#  1492.30889968,
#  1324.55915704,
#  947.58352444,
#  1335.469278,
#  1353.35548272,
#  1426.88231087,
#  628.56379291,
#  1002.77099429,
#  1416.66853469,
#  1955.49891784,
#  347.10246974,
#  846.43555654,
#  1792.52208633,
#  381.16158351,
#  'None',
#  1983.80798811,
#  1935.34928916,
#  1048.05745199,
#  'None',
#  1389.93700085,
#  1426.88231087,
#  1813.07328284,
#  1045.72850247,
#  1268.91268062,
#  'None',
#  1172.91316894,
#  956.3164466,
#  593.01771568,
#  1691.1877177,
#  1428.45815568,
#  212.84409222,
#  1653.26880191,
#  1268.91268062,
#  1315.50275712,
#  1731.0756509,
#  1773.3872601,
#  1132.00997994,
#  'None',
#  1858.64707037,
#  1320.04265213,
#  1917.954107,
#  1082.02868059,
#  675.67528155,
#  1882.44305638,
#  1372.36841596,
#  962.21482174,
#  'None',
#  1830.26612753,
#  1900.80957133,
#  777.55320349,
#  792.46977755,
#  'None',
#  1769.41346818,
#  838.46228768,
#  969.28481822,
#  764.47091698,
#  1384.59281683,
#  1818.05627627,
#  1858.62585177,
#  1270.28569507,
#  1366.32275232,
#  1847.97432154,
#  1397.63048487,
#  419.81439925,
#  1183.43637708,
#  1060.38043737,
#  1700.61406544,
#  1804.83275959,
#  'None',
#  976.74925192,
#  1165.32729441,
#  1087.45683269,
#  610.70945463,
#  894.6066266,
#  894.6066266,
#  731.18027182,
#  1931.18261027,
#  1965.58306617,
#  1293.99408391,
#  1645.25195566,
#  839.67852293,
#  1575.04939924,
#  1502.55961963,
#  462.94462029,
#  'None',
#  978.68001311,
#  'None',
#  'None',
#  805.56443652,
#  1861.54710766,
#  'None',
#  1166.61425877,
#  1610.60671641,
#  1134.69106155,
#  1934.82005512,
#  1166.61425877,
#  1005.91328337,
#  609.14807823,
#  990.97806147,
#  1007.81413549,
#  1169.97638646,
#  'None',
#  1353.35548272,
#  1128.38157722,
#  1865.70344368,
#  1121.69914751,
#  1585.65368135,
#  1581.59667549,
#  1800.84362603,
#  'None',
#  838.46228768,
#  1682.12600652,
#  344.05695759,
#  1465.63888252,
#  'None',
#  1133.74740376,
#  1707.46370369,
#  1648.18832048,
#  1270.50637683,
#  'None',
#  774.65330211,
#  1793.87626664,
#  942.39968431,
#  1839.83607034,
#  'None',
#  1439.75541627,
#  951.61779215,
#  'None',
#  1157.94069062,
#  'None',
#  963.743269,
#  1066.4946312,
#  965.10896018,
#  1354.10577619,
#  1722.40691839,
#  504.80959106,
#  1921.93332287,
#  750.67417711,
#  478.63327179,
#  738.85352441,
#  1053.60384845,
#  1024.32616792,
#  1908.54067332,
#  798.07341917,
#  1299.30966273,
#  515.84641272,
#  786.223628,
#  1510.57334158,
#  'None',
#  877.25925337,
#  1953.06222536,
#  1325.17555657,
#  1174.79196911,
#  1048.05745199,
#  1364.75788214,
#  1028.32356406,
#  1797.70936166,
#  1467.93040695,
#  1407.6444523,
#  1630.59410899,
#  1464.26640816,
#  'None',
#  1199.57072688,
#  545.81390439,
#  'None',
#  1331.7206754,
#  1687.36431041,
#  1354.1202544,
#  1856.67539826,
#  1040.98243019,
#  1354.1202544,
#  1151.07885002,
#  476.6395328,
#  930.41442631,
#  1847.45457601,
#  399.88693586,
#  1297.65224892,
#  1066.4946312,
#  'None',
#  1814.49335498,
#  1106.39496651,
#  1664.46112748,
#  696.94122651,
#  973.28052407,
#  741.72576648,
#  1270.86072087,
#  'None',
#  1574.41568287,
#  454.01314383,
#  1743.85526239,
#  706.89369047,
#  797.9053722,
#  693.1336645,
#  1447.18157178,
#  1073.74911839,
#  1724.60284354,
#  1901.6790944,
#  817.34804853,
#  549.79741356,
#  1044.48955598,
#  1781.55765445,
#  'None',
#  1624.32214479,
#  545.81390439,
#  'None',
#  1188.93395374,
#  'None',
#  1065.39096697,
#  1631.79636366,
#  1733.79338163,
#  562.24377339,
#  594.36097513,
#  1357.73159583,
#  1913.58004009,
#  1869.04586043,
#  365.48903076,
#  'None',
#  'None',
#  1896.02510552,
#  'None',
#  'None',
#  'None',
#  596.13194421,
#  'None',
#  1328.72786858,
#  1066.4946312,
#  1146.51659827,
#  'None',
#  690.31406231,
#  670.08058528,
#  1180.05653453,
#  877.3891429,
#  1956.72710049,
#  'None',
#  463.82804462,
#  1038.13531793,
#  520.49781203,
#  1951.34525134,
#  1968.67166088,
#  961.79458589,
#  1497.61914283,
#  1558.63760483,
#  285.03305671,
#  445.07286983,
#  1823.85729299,
#  390.85882124,
#  'None',
#  'None',
#  936.38683713,
#  1908.89515928,
#  1704.81836957,
#  1703.72862918,
#  1806.12183231,
#  942.39968431,
#  'None',
#  1009.40702305,
#  359.60560095,
#  1688.19355222,
#  'None',
#  1203.06704222,
#  1947.65907218,
#  568.54187389,
#  1850.05336991,
#  1005.47142691,
#  377.61946927,
#  1979.05980607,
#  640.51283397,
#  1961.10357032,
#  1572.89693277,
#  'None',
#  503.59678818,
#  1079.17417202,
#  1821.15686967,
#  1634.7819226,
#  1385.13715678,
#  1164.0772119,
#  1401.96584478,
#  628.56379291,
#  'None',
#  1134.67952625,
#  338.4480372,
#  1916.25720662,
#  'None',
#  1774.71741339,
#  957.20666058,
#  1930.99149545,
#  1898.42892253,
#  1468.14595216,
#  764.23047405,
#  937.05212737,
#  994.52479846,
#  'None',
#  457.2388341,
#  1279.13321858,
#  1132.00997994,
#  1617.14446715,
#  1609.19930359,
#  1407.40496761,
#  1866.59395063,
#  1842.50139502,
#  1034.80079629,
#  1669.64702678,
#  420.07360012,
#  1304.4110647,
#  1606.61542039,
#  492.76894146,
#  1669.45003369,
#  939.77424981,
#  1885.38346449,
#  1519.35478709,
#  1816.58864822,
#  1241.13739718,
#  1809.46438081,
#  237.80028968,
#  'None',
#  1863.78816445,
#  'None',
#  1618.74481695,
#  1555.0852338,
#  'None',
#  'None',
#  1288.95792927,
#  'None',
#  867.36844858,
#  451.36363443,
#  315.31443708,
#  1973.59789861,
#  576.39699954,
#  681.89920403,
#  160.27956119,
#  1844.68410035,
#  'None',
#  918.52360094,
#  395.70535354,
#  'None',
#  1170.81335634,
#  1505.02291997,
#  1252.63898025,
#  176.2253789,
#  968.48203084,
#  1708.65482019,
#  945.50274583,
#  1962.70952707,
#  463.34399554,
#  1005.91328337,
#  1809.52552966,
#  308.26693508,
#  'None',
#  919.88780331,
#  354.22711107,
#  1728.92946979,
#  1005.91328337,
#  'None',
#  750.67417711,
#  1481.22745447,
#  1362.26274461,
#  'None',
#  'None',
#  1338.51243168,
#  478.63327179,
#  758.59839008,
#  1739.07227544,
#  1338.12009634,
#  1203.57021295,
#  1195.3366901,
#  676.4554984,
#  1417.38579773,
#  1773.79731013,
#  1453.35676527,
#  1250.21684792,
#  1411.03090148,
#  497.15510967,
#  1360.42391894,
#  1377.71602547,
#  202.34179026,
#  1548.50475777,
#  1693.60055441,
#  1569.58637973,
#  1597.97078824,
#  'None',
#  1938.67887635,
#  1730.32554661,
#  1914.61383688,
#  1806.54569426,
#  44.24944959,
#  356.88391308,
#  'None',
#  1745.37638929,
#  1179.25879881,
#  1864.17810137,
#  'None',
#  1621.37156717,
#  893.42594823,
#  559.03446273,
#  1711.70342473,
#  509.91253757,
#  'None',
#  1815.09159184,
#  'None',
#  1093.79321681,
#  1729.90032846,
#  'None',
#  520.49781203,
#  'None',
#  1599.04066505,
#  297.44755324,
#  1568.08237646,
#  'None',
#  1358.9798911,
#  'None',
#  'None',
#  'None',
#  963.7541482,
#  1100.09140726,
#  'None',
#  1927.61762495]

# %%
len(distance)
# Out:
# 500

# %%
df = pd.DataFrame (distance)
df
# Out:
#                0
# 0      528.00941
# 1    1874.739115
# 2    1897.717585
# 3     382.229357
# 4    1518.409268
# ..           ...
# 495         None
# 496   963.754148
# 497  1100.091407
# 498         None
# 499  1927.617625
#
# [500 rows x 1 columns]

# %%
df.to_csv("distance2000.csv")

# %% [markdown]
# ## 2000-2500

# %%
distance=[]

# %%
for i in cord[2001:2021]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File ~/miniconda3/envs/ads/lib/python3.8/http/client.py:1348, in HTTPConnection.getresponse(self)
#    1347 try:
# -> 1348     response.begin()
#    1349 except ConnectionError:
#
# File ~/miniconda3/envs/ads/lib/python3.8/http/client.py:316, in HTTPResponse.begin(self)
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#
# File ~/miniconda3/envs/ads/lib/python3.8/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#
# File ~/miniconda3/envs/ads/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     668 try:
# --> 669     return self._sock.recv_into(b)
#     670 except timeout:
#
# File ~/miniconda3/envs/ads/lib/python3.8/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#
# File ~/miniconda3/envs/ads/lib/python3.8/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1098 if buffer is not None:
# -> 1099     return self._sslobj.read(len, buffer)
#    1100 else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/urllib3/util/retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/urllib3/packages/six.py:770, in reraise(tp, value, tb)
#     769         raise value.with_traceback(tb)
# --> 770     raise value
#     771 finally:
#
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/urllib3/connectionpool.py:451, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     452     raise
#
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/urllib3/connectionpool.py:340, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     339 if isinstance(err, SocketTimeout):
# --> 340     raise ReadTimeoutError(
#     341         self, url, "Read timed out. (read timeout=%s)" % timeout_value
#     342     )
#     344 # See the above comment about EAGAIN in Python 3. In Python 2 we have
#     345 # to specifically catch it and throw the timeout error
#
# ReadTimeoutError: HTTPSConnectionPool(host='api.openrouteservice.org', port=443): Read timed out. (read timeout=60)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/openrouteservice/client.py:186, in Client.request(self, url, get_params, first_request_time, retry_counter, requests_kwargs, post_json, dry_run)
#     185 try:
# --> 186     response = requests_method(self._base_url + authed_url,
#     187                                **final_requests_kwargs)
#     188     self._req = response.request
#
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/requests/sessions.py:635, in Session.post(self, url, data, json, **kwargs)
#     625 r"""Sends a POST request. Returns :class:`Response` object.
#     626
#     627 :param url: URL for the new :class:`Request` object.
#    (...)
#     632 :rtype: requests.Response
#     633 """
# --> 635 return self.request("POST", url, data=data, json=json, **kwargs)
#
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/requests/adapters.py:578, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     577 elif isinstance(e, ReadTimeoutError):
# --> 578     raise ReadTimeout(e, request=request)
#     579 elif isinstance(e, _InvalidHeader):
#
# ReadTimeout: HTTPSConnectionPool(host='api.openrouteservice.org', port=443): Read timed out. (read timeout=60)
#
# During handling of the above exception, another exception occurred:
#
# Timeout                                   Traceback (most recent call last)
# /home/jericho/Project 2/generic-real-estate-consulting-project-group-29/notebooks/train station.ipynb Cell 130 in <cell line: 1>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jericho/Project%202/generic-real-estate-consulting-project-group-29/notebooks/train%20station.ipynb#Y243sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> for i in cord[2001:2021]:
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jericho/Project%202/generic-real-estate-consulting-project-group-29/notebooks/train%20station.ipynb#Y243sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     geojson = {"type": "point", "coordinates": i}
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jericho/Project%202/generic-real-estate-consulting-project-group-29/notebooks/train%20station.ipynb#Y243sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     pois = client.places(
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jericho/Project%202/generic-real-estate-consulting-project-group-29/notebooks/train%20station.ipynb#Y243sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>         request='pois',
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jericho/Project%202/generic-real-estate-consulting-project-group-29/notebooks/train%20station.ipynb#Y243sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>         geojson=geojson,
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jericho/Project%202/generic-real-estate-consulting-project-group-29/notebooks/train%20station.ipynb#Y243sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>         buffer=2000,  # searches within 2000 meters of specified point
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jericho/Project%202/generic-real-estate-consulting-project-group-29/notebooks/train%20station.ipynb#Y243sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>         filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jericho/Project%202/generic-real-estate-consulting-project-group-29/notebooks/train%20station.ipynb#Y243sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>         validate=False,
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jericho/Project%202/generic-real-estate-consulting-project-group-29/notebooks/train%20station.ipynb#Y243sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a>
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jericho/Project%202/generic-real-estate-consulting-project-group-29/notebooks/train%20station.ipynb#Y243sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a>     )
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jericho/Project%202/generic-real-estate-consulting-project-group-29/notebooks/train%20station.ipynb#Y243sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>     if len(pois['features']) == 0:
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jericho/Project%202/generic-real-estate-consulting-project-group-29/notebooks/train%20station.ipynb#Y243sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a>         distance.append("None")
#
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/openrouteservice/client.py:299, in _make_api_method.<locals>.wrapper(*args, **kwargs)
#     296 @functools.wraps(func)
#     297 def wrapper(*args, **kwargs):
#     298     args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 299     result = func(*args, **kwargs)
#     300     try:
#     301         del args[0]._extra_params
#
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/openrouteservice/places.py:115, in places(client, request, geojson, bbox, buffer, filter_category_ids, filter_category_group_ids, filters_custom, limit, sortby, validate, dry_run)
#     112     if sortby:
#     113         params['sortby'] = sortby
# --> 115 return client.request('/pois', {}, post_json=params, dry_run=dry_run)
#
# File ~/miniconda3/envs/ads/lib/python3.8/site-packages/openrouteservice/client.py:191, in Client.request(self, url, get_params, first_request_time, retry_counter, requests_kwargs, post_json, dry_run)
#     188     self._req = response.request
#     190 except requests.exceptions.Timeout:
# --> 191     raise exceptions.Timeout()
#     193 if response.status_code in _RETRIABLE_STATUSES:
#     194     # Retry request.
#     195     warnings.warn('Server down.\nRetrying for the {0}{1} time.'.format(retry_counter + 1,
#     196                                                                        get_ordinal(retry_counter + 1)),
#     197                   UserWarning,
#     198                   stacklevel=1)
#
# Timeout:

# %%
for i in cord[2021:2041]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2041:2061]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2061:2081]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2081:2101]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2101:2121]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2121:2141]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2141:2161]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2161:2181]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2181:2201]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2201:2221]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2221:2241]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2241:2261]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2261:2281]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2281:2301]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2301:2321]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2321:2341]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2341:2361]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])
# Out:
# /home/jericho/miniconda3/envs/ads/lib/python3.8/site-packages/openrouteservice/client.py:211: UserWarning: Rate limit exceeded. Retrying for the 1st time.
#   warnings.warn('Rate limit exceeded. Retrying for the {0}{1} time.'.format(retry_counter + 1,
# /home/jericho/miniconda3/envs/ads/lib/python3.8/site-packages/openrouteservice/client.py:211: UserWarning: Rate limit exceeded. Retrying for the 2nd time.
#   warnings.warn('Rate limit exceeded. Retrying for the {0}{1} time.'.format(retry_counter + 1,
# /home/jericho/miniconda3/envs/ads/lib/python3.8/site-packages/openrouteservice/client.py:211: UserWarning: Rate limit exceeded. Retrying for the 3rd time.
#   warnings.warn('Rate limit exceeded. Retrying for the {0}{1} time.'.format(retry_counter + 1,

# %%
for i in cord[2361:2381]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])
# Out:
# /home/jericho/miniconda3/envs/ads/lib/python3.8/site-packages/openrouteservice/client.py:211: UserWarning: Rate limit exceeded. Retrying for the 4th time.
#   warnings.warn('Rate limit exceeded. Retrying for the {0}{1} time.'.format(retry_counter + 1,

# %%
for i in cord[2381:2401]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2401:2421]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2421:2441]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2441:2461]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2461:2481]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])
# Out:
# /home/jericho/miniconda3/envs/ads/lib/python3.8/site-packages/openrouteservice/client.py:211: UserWarning: Rate limit exceeded. Retrying for the 5th time.
#   warnings.warn('Rate limit exceeded. Retrying for the {0}{1} time.'.format(retry_counter + 1,

# %%
for i in cord[2481:2501]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
len(distance)
# Out:
# 500

# %%
df = pd.DataFrame (distance)
df
# Out:
#                0
# 0     668.494125
# 1           None
# 2     1915.47223
# 3    1170.842091
# 4           None
# ..           ...
# 495  1396.276755
# 496         None
# 497         None
# 498  1285.622228
# 499  1574.286989
#
# [500 rows x 1 columns]

# %%
df.to_csv("distance2500.csv")

# %% [markdown]
# ## 2500-3000

# %%
client = ors.Client(key='5b3ce3597851110001cf62481ecd75c979304406b4489e4fcb28fc34')

# %%
distance=[]

# %%
for i in cord[2501:2521]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2521:2541]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2541:2561]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2561:2581]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2581:2601]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2601:2621]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2621:2641]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2641:2661]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2661:2681]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2681:2701]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2701:2721]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2721:2741]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2741:2761]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2761:2781]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2781:2801]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2801:2821]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2821:2841]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2841:2861]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
for i in cord[2861:]:
    geojson = {"type": "point", "coordinates": i}
    pois = client.places(
        request='pois',
        geojson=geojson,
        buffer=2000,  # searches within 2000 meters of specified point
        filter_category_ids=[604],  # https://github.com/GIScience/openpoiservice/blob/master/openpoiservice/server/categories/categories.yml
        validate=False,
        
    )
    if len(pois['features']) == 0:
        distance.append("None")
    else:
        distance.append(pois['features'][0]['properties']['distance'])

# %%
len(distance)
# Out:
# 481

# %%
#distance.pop(-1)

# %%
df = pd.DataFrame (distance)
df
# Out:
#                0
# 0           None
# 1     829.455069
# 2    1937.438105
# 3    1284.562632
# 4    1599.131711
# ..           ...
# 476  1724.349795
# 477  1265.559717
# 478  1626.707023
# 479         None
# 480  1380.371329
#
# [481 rows x 1 columns]

# %%
df.to_csv("distance3000.csv")

# %%
df1 = pd.read_csv('distance500.csv')
df2 = pd.read_csv('distance1000.csv')
df3 = pd.read_csv('distance1500.csv')
df4 = pd.read_csv('distance2000.csv')
df5 = pd.read_csv('distance2500.csv')
df6 = pd.read_csv('distance3000.csv')

# %%
df= df1.append(df2)
df= df.append(df3)
df= df.append(df4)
df= df.append(df5)
df= df.append(df6)
df.to_csv("distance_to_trainstation.csv")
